# %%
import requests

# %%
data = requests.get('https://platform.stratascratch.com/coding/output-preview')

# %%
data.status_code
# Out:
# 200

# %%
html = data.text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link as="font" crossorigin="" href="/_next/static/media/0e4fe491bf84089c-s.p.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/_next/static/media/627622453ef56b0d-s.p.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/_next/static/media/934c4b7cb736f2a3-s.p.woff2" rel="preload" type="font/woff2"/>
#   <link data-precedence="next" href="/_next/static/css/bc3a9d94c882ad41.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/69e213bc52ee8121.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/8461904cb1fd111b.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/e1841321d201dda7.css" rel="stylesheet"/>
# ...

# %%
table_rows = soup.find_all('tr')

# %%
len(table_rows)
# Out:
# 0

# %%
soup.title
# Out:
# <title>StrataScratch - Login</title>
